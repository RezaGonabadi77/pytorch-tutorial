# %%
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
filename1= r'BonnEEG\S001.txt'
filename2= r'BonnEEG\Z001.txt'
df1= pd.read_csv(filename1,header=None)
df2= pd.read_csv(filename2,header=None)
# sig= df.iloc[:,0].values
sig1= df1.iloc[:,0].to_numpy()
sig2= df2.iloc[:,0].to_numpy()

plt.subplot(2,1,1)
plt.plot(sig1)
plt.subplot(2,1,2)
plt.plot(sig2)
plt.show()
