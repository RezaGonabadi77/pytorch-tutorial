# %%
import torch
import glob
import matplotlib.pyplot as plt
import numpy as np

# %%
path_name = r'dataset'
data_list = glob.glob(pathname= path_name + '\*')

# %%
data = []
for data_name in data_list:
    data.append(np.loadtxt(data_name))
    
data_numpy = np.array(data)

# %%
data_tensor = torch.from_numpy(data_numpy).to(torch.float32)

# %%
plt.plot(data_numpy[4,:])
plt.show()
